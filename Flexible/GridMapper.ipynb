# %%
# %load_ext autoreload
# %autoreload 2

# %%
# imports
from datetime import datetime
import sqlite3
from sqlite3 import Error
import pandas as pd
from geopy import distance
import math
import time
import utilities as ut

# %%
pd.options.mode.chained_assignment = None

# %%
DB = "/Users/funsooje/Documents/GTL/DB/gtlc3.db"
conn = sqlite3.connect(DB)
earthRadius = 6371 # this is in KM

# %%
# Functions
l_e_upperLat = 0
l_e_lowerLat = 0
l_e_upperLon = 0
l_e_lowerLon = 0
l_e_id = 0
l_e_level = 0


def linkGrid(lon, lat, locid, approx = True):
#check if grids are empty
    c = conn.cursor()
    c.execute("""select exists (select 1 from locationGrids)""")
    cc = c.fetchall()
    cc = cc[0][0]
    if cc == 0:
        gridId = createNewGrid(lon, lat)
        # return saveLocGrid(locid, gridId)

    # find exact match first
    gridId = findExactGrid(lon, lat)
    
    if gridId == 0:
        if approx: 
            # create the new grid from self
            gridId = createNewGrid(lon, lat)
        else: 
            # if no match, find closest and calculate exact match
            closestCenLon, closestCenLat, _ = findClosestGrid(lon, lat)
            # resolve the lon
            nULon, nLLon, nULat, nLLat = getNewGridParams(closestCenLon, closestCenLat)

            while not (nULon >= lon and nLLon <= lon):
                brng = 90 if lon > closestCenLon else -90
                closestCenLon = round(tuple(distance.distance(meters=50).destination((closestCenLat, closestCenLon), bearing=brng))[1], 7)
                nULon, nLLon, nULat, nLLat = getNewGridParams(closestCenLon, closestCenLat)

            while not (nULat >= lat and nLLat <= lat):
                brng = 0 if lat > closestCenLat else 180
                closestCenLat = round(tuple(distance.distance(meters=50).destination((closestCenLat, closestCenLon), bearing=brng))[0], 7)
                nULon, nLLon, nULat, nLLat = getNewGridParams(closestCenLon, closestCenLat)

            gridId = createNewGrid(closestCenLon, closestCenLat)
    # create new location grid
    if gridId > 0:
        return saveLocGrid(locid, gridId)



def saveLocGrid(locid, gridId):
    c = conn.cursor()
    sql = "insert into locationGrids(locationId, gridId) VALUES(" + str(locid) + "," + str(gridId) + ")"
    c.execute(sql)
    conn.commit()
    return c.lastrowid



def getNewGridParams(lon, lat, level = 1):
    # get limits
    mDis = (math.pow(2, level-1) * 25)  # 2 meter overlap
    # print(lon, lat)
    upperLat = round(tuple(distance.distance(meters=mDis).destination((lat, lon), bearing=0))[0], 7)
    lowerLat = round(tuple(distance.distance(meters=mDis).destination((lat, lon), bearing=180))[0], 7)
    upperLon = round(tuple(distance.distance(meters=mDis).destination((lat, lon), bearing=90))[1], 7)
    lowerLon = round(tuple(distance.distance(meters=mDis).destination((lat, lon), bearing=-90))[1], 7)
    return upperLon, lowerLon, upperLat, lowerLat


def createNewGrid(lon, lat, level = 1):
    centerLat = lat
    centerLon = lon

    # get limits
    upperLon, lowerLon, upperLat, lowerLat = getNewGridParams(lon, lat, level)

    # save to database
    c = conn.cursor()
    #save to db
    sql = """ insert into grids(centerLon, centerLat, upperLon, upperLat, lowerLon, lowerLat, level) VALUES(?,?,?,?,?,?,?)  """
    vals = (centerLon, centerLat, upperLon, upperLat, lowerLon, lowerLat, level)
    c.execute(sql, vals)
    conn.commit()
    return c.lastrowid


def findExactGrid(lon, lat, level = 1):
    global l_e_id
    global l_e_upperLat
    global l_e_lowerLat
    global l_e_upperLon
    global l_e_lowerLon
    global l_e_level
    
    if l_e_id > 0:
        if l_e_upperLat >= lat and l_e_lowerLat <= lat and l_e_upperLon >= lon and l_e_lowerLon <= lon and level == l_e_level:
            return l_e_id
    c = conn.cursor()
    c.execute("""select id, upperLat, lowerLat, upperLon, lowerLon from grids 
                where upperLat >= ?
                AND lowerLat <= ?
                AND upperLon >= ?
                AND lowerLon <= ?
                AND level = ? 
                LIMIT 1
                """, 
                (lat, lat, lon, lon, level))
    cc = pd.DataFrame(c.fetchall())
    if len(cc) > 0:
        l_e_id = cc[0][0]
        l_e_upperLat = cc[1][0]
        l_e_lowerLat = cc[2][0]
        l_e_upperLon = cc[3][0]
        l_e_lowerLon = cc[4][0]
        l_e_level = level
        return l_e_id
    else:
        l_e_id = 0
        return l_e_id
   

def findClosestGrid(lon, lat, level = 1):
    c = conn.cursor()

    c.execute("""SELECT
                    centerLon, centerLat,
                    ABS(centerLat - ?) + ABS(centerLon - ?) AS closest
                FROM
                    grids
                WHERE
                    level = ?
                ORDER BY
                    closest
                LIMIT 1
                """, 
                (lat, lon, level))
    cc = pd.DataFrame(c.fetchall())
    if len(cc) > 0:
        return cc[0][0], cc[1][0], True
    else:
        return 0, 0, False


def mapParent(gridID, lon, lat, level, approx = True):
    # find exact grid of parent
    parentLevel = level + 1
    parentGridId = findExactGrid(lon, lat, parentLevel)
    # match - update grid
    if parentGridId > 0: 
        updateParent(gridID, parentGridId)
        return
    # no match
    if approx: 
        parentGridId = createNewGrid(lon, lat, parentLevel)
        updateParent(gridID, parentGridId)
        return
    else:
        # - find parent closest grid
        closestCenLon, closestCenLat, isExist = findClosestGrid(lon, lat, parentLevel)
        if mDebug:
            print("Closest Grid: ", end = "")
            print(closestCenLon, closestCenLat, isExist)

        # no match - create first parent grid 
        if not isExist:
            nULon, nLLon, nULat, nLLat = getNewGridParams(lon, lat, parentLevel)
            # create using the edge and not the center
            parentGridId = createNewGrid(nLLon, nLLat, parentLevel)
            updateParent(gridID, parentGridId)
            return
        # match 
        mDis = math.pow(2, parentLevel-1) * 25
        jumpDis = ((mDis * 2)) # 2 meter overlap

        # find distance between closest and current on lat
        
        mC = 0
        nULon, nLLon, nULat, nLLat = getNewGridParams(closestCenLon, closestCenLat, parentLevel)
        while not (nULat >= lat and nLLat <= lat):
            closestCenter = (closestCenLat, closestCenLon)
            poI = (lat, closestCenLon)
            disccc = distance.distance(closestCenter, poI).meters
            jumps = int(disccc / jumpDis)
            jumps = 1 if jumps == 0 else jumps
            mC += 1
            brng = 0 if lat > closestCenLat else 180
            closestCenLat = round(tuple(distance.distance(meters=(jumpDis * jumps)).destination((closestCenLat, closestCenLon), bearing=brng))[0], 7)
            nULon, nLLon, nULat, nLLat = getNewGridParams(closestCenLon, closestCenLat)
            if mDebug:
                print(mC, jumps, nULon, nLLon, nULat, nLLat, closestCenLat, brng)
            # print(closestCenLon, closestCenLat)
            # print(nULon, nLLon, nULat, nLLat)
            if mC > 100:
                break

        # find distance between closest and current on lon
        # check a few times
        mC = 0    
        nULon, nLLon, nULat, nLLat = getNewGridParams(closestCenLon, closestCenLat, parentLevel)
        while not (nULon >= lon and nLLon <= lon):
            closestCenter = (closestCenLat, closestCenLon)
            poI = (closestCenLat, lon)
            disccc = distance.distance(closestCenter, poI).meters
            jumps = int(disccc / jumpDis)
            jumps = 1 if jumps == 0 else jumps
            mC += 1
            brng = 90 if lon > closestCenLon else -90
            closestCenLon = round(tuple(distance.distance(meters=jumpDis * jumps).destination((closestCenLat, closestCenLon), bearing=brng))[1], 7)
            nULon, nLLon, nULat, nLLat = getNewGridParams(closestCenLon, closestCenLat, parentLevel)
            if mDebug:
                print(mC, jumps, nULon, nLLon, nULat, nLLat, closestCenLon, brng)
            if mC > 100:
                break 
        
        if mDebug:
            print("upper lon", nULon - lon)
            print("lower lon", nLLon - lon)
            print("upper lat", nULat - lat)
            print("lower lat", nLLat - lat)

        # create the new grid from the new center
        if nULat >= lat and nLLat <= lat and nULon >= lon and nLLon <= lon:
            parentGridId = createNewGrid(closestCenLon, closestCenLat, parentLevel)
            updateParent(gridID, parentGridId)
        else:
            # update to bad grid to be revisited
            updateParent(gridID, -1)
        return
    

def updateParent(gridID, parentGridId):
    c = conn.cursor()
    c.execute("update grids set parentID = " + str(parentGridId) + " where id = " + str(gridID))
    conn.commit()
    return

# %%
# %%script false --no-raise-error
# # old method
# # get no parent grids and process parents
# mDebug = False
#
# def updateParentGrids(limit = 1):
#     conn = None
#     try:
#         conn = sqlite3.connect(DB)
#         c = conn.cursor()
#         c.execute("""SELECT
#         id,
#         centerLon,
#         centerLat,
#         level
#     FROM
#         grids
#     WHERE
#         level < 15
#         AND parentID IS NULL
#     ORDER BY
#         level DESC, centerLat, centerLon
#         """)
#         noParentGrids = c.fetchall()
#
#         noParentGrids = pd.DataFrame(noParentGrids)
#         if len(noParentGrids) < limit:
#             return 0
#
#         print(str(len(noParentGrids)), "no parent grids found")
#
#         for index, row in noParentGrids.iterrows():
#             gridID = row[0]
#             lon = row[1]
#             lat = row[2]
#             level = int(row[3])
#             if mDebug:
#                 print(gridID, lat, lon, level)
#             mapParent(gridID, lon, lat, level)
#             if index % 1000 == 0:
#                 print(str(index), " of ", str(len(noParentGrids)), " - ", str(round(index / len(noParentGrids) * 100, 2)),
#                             "%")
#         #     if index > 5000:
#         #         break # for
#         #     break # for
#         # break # while
#         return len(noParentGrids)
#     except Error as e:
#         sys.exit(e)
#     finally:
#         if conn:
#             conn.close()

# %%
# %%script false --no-raise-error
# # old method
# # get walking locations without grids
# cc = 0
# while True:
#     conn = None
#     try:
#         conn = sqlite3.connect(DB)
#         c = conn.cursor()
#         cquery = """
#         SELECT
#             loc.id AS location_id,
#             loc.longitude AS location_longitude,
#             loc.latitude AS location_latitude
#         FROM
#             locations loc
#             LEFT JOIN locationGrids lg ON lg.locationId = loc.id
#             WHERE lg.locationId IS NULL
#             ORDER BY location_longitude, location_latitude
#         LIMIT 10000
#         """
#         # cquery = "SELECT acs.location_id, acs.location_longitude, acs.location_latitude "
#         # cquery = cquery + " FROM v_loc_acs acs LEFT JOIN locationGrids lg ON lg.locationId = acs.location_id "
#         # cquery = cquery + " WHERE lg.locationId IS NULL "
#         # # cquery = cquery + " WHERE acs.activity = '" + run_act + "' AND lg.locationId IS NULL "
#         # cquery = cquery + " ORDER BY acs.location_longitude, acs.location_latitude LIMIT 10000"
#         c.execute(cquery)
#         noGridLocs = c.fetchall()
#
#         noGridLocs = pd.DataFrame(noGridLocs)
#         print(str(len(noGridLocs)), "no grid locations found")
#
#     except Error as e:
#         sys.exit(e)
#     finally:
#         if conn:
#             conn.close()
#
#     # run through and build level 1 grids
#     lenNoGrids = len(noGridLocs)
#     if lenNoGrids == 0:
#         break
#
#     start = time.process_time()
#     msgBreak = 10000
#
#     for index, row in noGridLocs.iterrows():
#         locID = row[0]
#         locLon = row[1]
#         locLat = row[2]
#
#         linkGrid(locLon, locLat, locID)
#
#         # if index % (msgBreak/10) == 0:
#         #     tt = round(time.process_time() - start, 2)
#         #     eta = round((lenNoGrids - index) / msgBreak * tt / 60, 2)
#         #     print("{} of {} - {}% - {} secs - est: {} mins".format(index,
#         #                                                             lenNoGrids,
#         #                                                             round(index / lenNoGrids * 100, 2),
#         #                                                             tt,
#         #                                                             eta))
#         #     updateParentGrids(5000)
#         #     start = time.process_time()
#     tt = round(time.process_time() - start, 2)
#     cc += 10000
#     print("{} of {} - {}% - {} - {} secs".format(index, lenNoGrids, round(index / lenNoGrids * 100, 2), cc, tt))
#     # updateParentGrids()

# %%
# %%script false --no-raise-error
# # old method
# # run until no more levels
# while True:
#     if updateParentGrids() == 0:
#         break

# %% [markdown]
# [ ] Get the batch
#
# [ ] Get min and max on lat and lon to get eligible parent grid
#
# [ ] run through batch and stack found matches
#
# [ ] run through batch and stack new parents
#
# [ ] push found batches and parents in one go

# %%
# approximate batched functions
def getEligibleParents(minLon, maxLon, minLat, maxLat, level = 1, debug = False):
    c = conn.cursor()
    cquery = """
    select id, upperLat, lowerLat, upperLon, lowerLon from grids 
                    where upperLat <= {}
                    AND lowerLat >= {}
                    AND upperLon <= {}
                    AND lowerLon >= {}
                    AND level = {}
    """.format(maxLat, minLat, maxLon, minLon, level)
    # c.execute("""select id, upperLat, lowerLat, upperLon, lowerLon from grids 
    #                 where upperLat <= ?
    #                 AND lowerLat >= ?
    #                 AND upperLon <= ?
    #                 AND lowerLon >= ?
    #                 AND level = ? 
    #                 """, 
    #                 (maxLat, minLat, maxLon, minLon, level))
    if debug:
        print(cquery)
    c.execute(cquery)
    cc = pd.DataFrame(c.fetchall()).rename(columns = {0: 'id', 1: 'upperLat', 2: 'lowerLat', 3: 'upperLon', 4: 'lowerLon'})
    return cc

def getParent(row, eligibleParents):
    lat = row['location_latitude']
    lon = row['location_longitude']
    if len(eligibleParents) == 0:
        return 0
    id = eligibleParents[(eligibleParents['upperLat'] >= lat) & 
                    (eligibleParents['lowerLat'] <= lat) & 
                    (eligibleParents['lowerLon'] <= lon) & 
                    (eligibleParents['lowerLon'] <= lon)]
    if (len(id) == 0):
        return 0
    else:
        return id.iat[0, 0]

def createUnmmapedParent(row, unmappedParentsDF, level = 1):
    lat = row['location_latitude']
    lon = row['location_longitude']
    centerLat = lat
    centerLon = lon

    # check unmappedParentsDF first
    if len(unmappedParentsDF) > 0:
        id = unmappedParentsDF[(unmappedParentsDF['upperLat'] >= lat) & 
                    (unmappedParentsDF['lowerLat'] <= lat) & 
                    (unmappedParentsDF['lowerLon'] <= lon) & 
                    (unmappedParentsDF['lowerLon'] <= lon)]
        if len(id) > 0:
            return None # it's already mapped - nothing to do

    # else: 
    # get limits
    upperLon, lowerLon, upperLat, lowerLat = getNewGridParams(lon, lat, level)

    a = {'centerLon': centerLon, 'centerLat': centerLat, 'upperLon': upperLon, 'upperLat': upperLat, 'lowerLon': lowerLon, 'lowerLat': lowerLat, 'level': level}
    return a

def padMinMax(minLat, minLon, maxLat, maxLon, level):
    if level >= 14:
        minLat -= 10
        minLon -= 10
        maxLat += 10
        maxLon += 10
    elif level >= 10:
        minLat -= 1
        minLon -= 1
        maxLat += 1
        maxLon += 1
    elif level >= 6:
        minLat -= 0.1
        minLon -= 0.1
        maxLat += 0.1
        maxLon += 0.1 
    else:
        minLat -= 0.01
        minLon -= 0.01
        maxLat += 0.01
        maxLon += 0.01
    return minLat, minLon, maxLat, maxLon

# %%
def runlocbatch(n = 10000):
    # Get the batch
    c = conn.cursor()
    cquery = """
    SELECT
        id AS location_id,
        longitude AS location_longitude,
        latitude AS location_latitude
    FROM
        locations
    WHERE gridId IS NULL
    ORDER BY location_longitude, location_latitude
    LIMIT {}
    """.format(n)
    c.execute(cquery)
    noGridLocs = c.fetchall()

    noGridLocs = pd.DataFrame(noGridLocs).rename(columns = {0: 'location_id', 1: 'location_longitude', 2: 'location_latitude'})
    
    if len(noGridLocs) == 0:
        return 0

    print(str(len(noGridLocs)), "no grid locations found")

    # get the unique no grid locs
    uniqueNoGridLocs = noGridLocs.drop_duplicates(subset=['location_longitude', 'location_latitude']).drop('location_id', axis = 1)

    print("{} unique locations found".format(len(uniqueNoGridLocs)))

    # get the min and max lon and lat
    minLon = min(uniqueNoGridLocs['location_longitude'])
    minLat = min(uniqueNoGridLocs['location_latitude'])
    maxLon = max(uniqueNoGridLocs['location_longitude'])
    maxLat = max(uniqueNoGridLocs['location_latitude'])

    minLat, minLon, maxLat, maxLon = padMinMax(minLat, minLon, maxLat, maxLon, 1)

    # get eligible level 1 parents
    l1Eligible = getEligibleParents(minLon, maxLon, minLat, maxLat)

    # get the ones that already have parents
    uniqueNoGridLocs['parentID'] = uniqueNoGridLocs.apply(getParent, args = (l1Eligible, ), axis = 1)

    # map to full list
    uniqueNoGridLocswithParents = uniqueNoGridLocs[uniqueNoGridLocs['parentID'] > 0]
    print("{:,} unique mapped locations found".format(len(uniqueNoGridLocswithParents)))

    mappedLocs = noGridLocs.merge(uniqueNoGridLocswithParents, how = 'inner').drop(columns = ['location_longitude', 'location_latitude']).rename(columns = {'location_id': 'locationId', 'parentID': 'gridId'})

    print("{:,} mapped locations found".format(len(mappedLocs)))

    # push mapped locations to DB
    chunksize = int(len(mappedLocs) / 11)
    n = mappedLocs.to_sql('locationGrids', conn, if_exists='replace', index = False, chunksize = 1000)

    cquery = """
    UPDATE
        locations
    SET
        gridId = lg.gridId
    FROM
        locationGrids lg
    WHERE
        locations.id = lg.locationId
    """
    c.execute(cquery)
    conn.commit()

    unmappedUnique = uniqueNoGridLocs[uniqueNoGridLocs['parentID'] == 0]

    ppcolumns = ['centerLon', 'centerLat', 'upperLon', 'upperLat', 'lowerLon', 'lowerLat', 'level']
    newParentsDF = pd.DataFrame(columns = ppcolumns)

    for _, row in unmappedUnique.iterrows():
        a = createUnmmapedParent(row, newParentsDF)
        if a:
            newParentsDF = pd.concat([newParentsDF, pd.DataFrame(a, index = [0])], ignore_index=True)

    print("{:,} unmmapped unique location - {:,} parents found".format(len(unmappedUnique), len(newParentsDF)))

    # push this to grids
    n = newParentsDF.to_sql('grids', conn, if_exists='append', index = False, chunksize=1000)
    return len(noGridLocs)

# %%
def runlevel(level, debug = False):
    c = conn.cursor()
    nextlevel = level + 1

    cquery = """
    SELECT
        id,
        centerLon,
        centerLat,
        level
    FROM
        grids
    WHERE
        level = {}
        AND parentID IS NULL
    ORDER BY 
        centerLat, centerLon
    """.format(level)
    c.execute(cquery)
    lgrids = pd.DataFrame(c.fetchall()).rename(columns = {0: 'id', 1: 'centerLon', 2: 'centerLat', 3: 'level'})

    if len(lgrids) == 0:
        return

    if debug:
        print(lgrids)

    print("{} level {} grids found".format(len(lgrids), level))

    minLon = min(lgrids['centerLon'])
    minLat = min(lgrids['centerLat'])
    maxLon = max(lgrids['centerLon'])
    maxLat = max(lgrids['centerLat'])

    minLat, minLon, maxLat, maxLon = padMinMax(minLat, minLon, maxLat, maxLon, nextlevel)

    if debug:
        print('minLat', 'minLon', 'maxLat', 'maxLon')
        print(minLat, minLon, maxLat, maxLon)

    lgrids['location_latitude'] = lgrids['centerLat']
    lgrids['location_longitude'] = lgrids['centerLon']

    # get eligible next level parents
    l1Eligible = getEligibleParents(minLon, maxLon, minLat, maxLat, nextlevel, debug)
    print("{} level {} parents found".format(len(l1Eligible), nextlevel))

    if debug: 
        print("Eligible Parents")
        print(l1Eligible)

    # get the ones that already have parents
    lgrids['parentID'] = lgrids.apply(getParent, args = (l1Eligible, ), axis = 1)

    # map to full list
    lgridsWithParents = lgrids[lgrids['parentID'] > 0].drop(columns = ['centerLon', 'centerLat', 'level', 'location_latitude', 'location_longitude'])
    print("\t{} grids with parents found".format(len(lgridsWithParents)))
    if debug:
        print(lgridsWithParents)

    # update grids with the following (id with parentID)
    lgridsWithParents.columns = ['gid', 'gParentID']
    if debug:
        print("grid with parents")
        print(lgridsWithParents)
    else:
        lgridsWithParents.to_sql('temp', conn, if_exists='replace', index = False, chunksize=1000)

        cquery = """
        UPDATE
            grids
        SET
            parentID = g2.gParentID
        FROM
            temp g2
        WHERE
            id = g2.gid
        """
        c.execute(cquery)
        conn.commit()

    # without parents
    lgridsNoParent = lgrids[lgrids['parentID'] == 0]

    ppcolumns = ['centerLon', 'centerLat', 'upperLon', 'upperLat', 'lowerLon', 'lowerLat', 'level']
    newParentsDF = pd.DataFrame(columns = ppcolumns)

    for _, row in lgridsNoParent.iterrows():
        a = createUnmmapedParent(row, newParentsDF, nextlevel)
        if a:
            newParentsDF = pd.concat([newParentsDF, pd.DataFrame(a, index = [0])], ignore_index=True)

    print("\t{} grids with no parents - {} unique parents found".format(len(lgridsNoParent), len(newParentsDF)))

    # push this to grids
    if debug:
        print("new Parents")
        print(newParentsDF)
    else:
        n = newParentsDF.to_sql('grids', conn, if_exists='append', index = False, chunksize=1000)

# %%
cc = 0
while True:
    c = runlocbatch(1_000_000)
    cc += c
    print("\t{:,} locations processed".format(cc))
    if c == 0:
        break
# Out:
# 1000000 no grid locations found
# 682221 unique locations found
# 664,127 unique mapped locations found
# 961,906 mapped locations found
# 18,094 unmmapped unique location - 3,381 parents found
# 	1,000,000 locations processed
# 1000000 no grid locations found
# 703805 unique locations found
# 703,704 unique mapped locations found
# 999,870 mapped locations found
# 101 unmmapped unique location - 52 parents found
# 	2,000,000 locations processed
# 1000000 no grid locations found
# 728172 unique locations found
# 712,212 unique mapped locations found
# 983,086 mapped locations found
# 15,960 unmmapped unique location - 1,394 parents found
# 	3,000,000 locations processed
# 1000000 no grid locations found
# 604406 unique locations found
# 598,061 unique mapped locations found
# 993,015 mapped locations found
# 6,345 unmmapped unique location - 1,176 parents found
# 	4,000,000 locations processed
# 1000000 no grid locations found
# 483935 unique locations found
# 476,096 unique mapped locations found
# 990,719 mapped locations found
# 7,839 unmmapped unique location - 1,192 parents found
# 	5,000,000 locations processed
# 1000000 no grid locations found
# 535371 unique locations found
# 535,206 unique mapped locations found
# 999,832 mapped locations found
# 165 unmmapped unique location - 120 parents found
# 	6,000,000 locations processed
# 1000000 no grid locations found
# 603416 unique locations found
# 596,116 unique mapped locations found
# 991,887 mapped locations found
# 7,300 unmmapped unique location - 997 parents found
# 	7,000,000 locations processed
# 1000000 no grid locations found
# 292765 unique locations found
# 292,738 unique mapped locations found
# 999,972 mapped locations found
# 27 unmmapped unique location - 20 parents found
# 	8,000,000 locations processed
# 1000000 no grid locations found
# 431214 unique locations found
# 192,437 unique mapped locations found
# 234,424 mapped locations found
# 238,777 unmmapped unique location - 1,045 parents found
# 	9,000,000 locations processed
# 1000000 no grid locations found
# 390687 unique locations found
# 390,081 unique mapped locations found
# 999,316 mapped locations found
# 606 unmmapped unique location - 343 parents found
# 	10,000,000 locations processed
# 1000000 no grid locations found
# 630117 unique locations found
# 613,587 unique mapped locations found
# 977,248 mapped locations found
# 16,530 unmmapped unique location - 4,549 parents found
# 	11,000,000 locations processed
# 1000000 no grid locations found
# 635023 unique locations found
# 631,385 unique mapped locations found
# 991,829 mapped locations found
# 3,638 unmmapped unique location - 1,585 parents found
# 	12,000,000 locations processed
# 1000000 no grid locations found
# 626373 unique locations found
# 626,373 unique mapped locations found
# 1,000,000 mapped locations found
# 0 unmmapped unique location - 0 parents found
# 	13,000,000 locations processed
# 1000000 no grid locations found
# 504592 unique locations found
# 8 unique mapped locations found
# 8 mapped locations found
# 504,584 unmmapped unique location - 49 parents found
# 	14,000,000 locations processed
# 1000000 no grid locations found
# 504587 unique locations found
# 504,587 unique mapped locations found
# 1,000,000 mapped locations found
# 0 unmmapped unique location - 0 parents found
# 	15,000,000 locations processed
# 1000000 no grid locations found
# 681922 unique locations found
# 641,412 unique mapped locations found
# 953,284 mapped locations found
# 40,510 unmmapped unique location - 4,548 parents found
# 	16,000,000 locations processed
# 1000000 no grid locations found
# 668326 unique locations found
# 650,538 unique mapped locations found
# 978,020 mapped locations found
# 17,788 unmmapped unique location - 1,191 parents found
# 	17,000,000 locations processed
# 1000000 no grid locations found
# 521742 unique locations found
# 467,428 unique mapped locations found
# 905,030 mapped locations found
# 54,314 unmmapped unique location - 9,132 parents found
# 	18,000,000 locations processed
# 252856 no grid locations found
# 167557 unique locations found
# 130,831 unique mapped locations found
# 195,358 mapped locations found
# 36,726 unmmapped unique location - 9,317 parents found
# 	18,252,856 locations processed
# 57498 no grid locations found
# 36726 unique locations found
# 36,726 unique mapped locations found
# 57,498 mapped locations found
# 0 unmmapped unique location - 0 parents found
# 	18,310,354 locations processed
# 	18,310,354 locations processed

# %%
for level in range(1, 15):
    print("Level: {}".format(level))
    runlevel(level)
    runlevel(level)
    print()
# Out:
# Level: 1
# 40091 level 1 grids found
# 930337 level 2 parents found
# 	26040 grids with parents found
# 	14051 grids with no parents - 11910 unique parents found
# 14051 level 1 grids found
# 942247 level 2 parents found
# 	14051 grids with parents found
# 	0 grids with no parents - 0 unique parents found
#
# Level: 2
# 11910 level 2 grids found
# 553347 level 3 parents found
# 	2710 grids with parents found
# 	9200 grids with no parents - 7171 unique parents found
# 9200 level 2 grids found
# 560381 level 3 parents found
# 	9200 grids with parents found
# 	0 grids with no parents - 0 unique parents found
#
# Level: 3
# 7171 level 3 grids found
# 315895 level 4 parents found
# 	1621 grids with parents found
# 	5550 grids with no parents - 4127 unique parents found
# 5550 level 3 grids found
# 319979 level 4 parents found
# 	5550 grids with parents found
# 	0 grids with no parents - 0 unique parents found
#
# Level: 4
# 4127 level 4 grids found
# 172733 level 5 parents found
# 	955 grids with parents found
# 	3172 grids with no parents - 2135 unique parents found
# 3172 level 4 grids found
# 174663 level 5 parents found
# 	3172 grids with parents found
# 	0 grids with no parents - 0 unique parents found
#
# Level: 5
# 2135 level 5 grids found
# 88269 level 6 parents found
# 	475 grids with parents found
# 	1660 grids with no parents - 1100 unique parents found
# 1660 level 5 grids found
# 86873 level 6 parents found
# 	1660 grids with parents found
# 	0 grids with no parents - 0 unique parents found
#
# Level: 6
# 1100 level 6 grids found
# 47521 level 7 parents found
# 	252 grids with parents found
# 	848 grids with no parents - 557 unique parents found
# 848 level 6 grids found
# 48062 level 7 parents found
# 	848 grids with parents found
# 	0 grids with no parents - 0 unique parents found
#
# Level: 7
# 557 level 7 grids found
# 26630 level 8 parents found
# 	117 grids with parents found
# 	440 grids with no parents - 304 unique parents found
# 440 level 7 grids found
# 26927 level 8 parents found
# 	440 grids with parents found
# 	0 grids with no parents - 0 unique parents found
#
# Level: 8
# 304 level 8 grids found
# 11109 level 9 parents found
# 	64 grids with parents found
# 	240 grids with no parents - 168 unique parents found
# 240 level 8 grids found
# 11277 level 9 parents found
# 	240 grids with parents found
# 	0 grids with no parents - 0 unique parents found
#
# Level: 9
# 168 level 9 grids found
# 6325 level 10 parents found
# 	38 grids with parents found
# 	130 grids with no parents - 88 unique parents found
# 130 level 9 grids found
# 6413 level 10 parents found
# 	130 grids with parents found
# 	0 grids with no parents - 0 unique parents found
#
# Level: 10
# 88 level 10 grids found
# 3424 level 11 parents found
# 	22 grids with parents found
# 	66 grids with no parents - 42 unique parents found
# 66 level 10 grids found
# 3427 level 11 parents found
# 	66 grids with parents found
# 	0 grids with no parents - 0 unique parents found
#
# Level: 11
# 42 level 11 grids found
# 1719 level 12 parents found
# 	15 grids with parents found
# 	27 grids with no parents - 16 unique parents found
# 27 level 11 grids found
# 1309 level 12 parents found
# 	27 grids with parents found
# 	0 grids with no parents - 0 unique parents found
#
# Level: 12
# 16 level 12 grids found
# 561 level 13 parents found
# 	5 grids with parents found
# 	11 grids with no parents - 8 unique parents found
# 11 level 12 grids found
# 560 level 13 parents found
# 	11 grids with parents found
# 	0 grids with no parents - 0 unique parents found
#
# Level: 13
# 8 level 13 grids found
# 292 level 14 parents found
# 	6 grids with parents found
# 	2 grids with no parents - 2 unique parents found
# 2 level 13 grids found
# 2 level 14 parents found
# 	2 grids with parents found
# 	0 grids with no parents - 0 unique parents found
#
# Level: 14
# 2 level 14 grids found
# 1 level 15 parents found
# 	0 grids with parents found
# 	2 grids with no parents - 1 unique parents found
# 2 level 14 grids found
# 2 level 15 parents found
# 	2 grids with parents found
# 	0 grids with no parents - 0 unique parents found

# %%
runlevel(14, True)

# %% [markdown]
# ## Level Updates
#
# l1y5_o
# l2y5_o
# l3y_o
# l9h

# %%
def getNewG1toG9():
    query = """
    SELECT * from v_g1tog9
    """
    g1tog9 = pd.read_sql(query, conn)
    return g1tog9

def getl9h():
    query = """
    SELECT gridId as l9, temporal from l9h
    """
    l9h = pd.read_sql(query, conn)
    return l9h

def getl3y_o():
    query = """
    SELECT gridId as l3, temporal from l3y_o
    """
    l3y_o = pd.read_sql(query, conn)
    return l3y_o

def getl2y5_o():
    query = """
    SELECT gridId as l2, temporal from l2y5_o
    """
    l2y5_o = pd.read_sql(query, conn)
    return l2y5_o

def getl1y5_o():
    query = """
    SELECT gridId as l1, temporal from l1y5_o
    """
    l1y5_o = pd.read_sql(query, conn)
    return l1y5_o

# %%
def l9hprocess(locations):
    
    clwl9 = locations[["l9", "temporal"]]
    clwl9['temporal'] = pd.to_datetime(clwl9['temporal'])
    clwl9 = clwl9.drop_duplicates()

    print("{} l9 unique matches".format(len(clwl9)))

    l9h = getl9h()
    l9h['temporal'] = pd.to_datetime(l9h['temporal'])
    clwl9 = clwl9.merge(l9h, how = 'left', indicator=True)
    clwl9 = clwl9[clwl9['_merge'] == 'left_only']
    clwl9 = clwl9[["l9", "temporal"]]

    print("{} l9h matches left".format(len(clwl9)))
    clwl9.rename(columns = {'l9': 'gridId'}, inplace=True)
    clwl9.to_sql('l9h', conn, if_exists='append', index = False, chunksize=1000)
    # print(clwl9.head())

def l3y_o_process(locations):
    clwl = locations[["l3", "temporal"]]
    clwl['datetime'] = clwl['temporal']
    clwl['temporal'] = clwl.apply(ut.yearsnap, axis = 1)
    clwl['temporal'] = pd.to_datetime(clwl['temporal'])
    
    clwl = clwl[['l3', 'temporal']]
    clwl = clwl.drop_duplicates()

    print("{} l3y unique matches".format(len(clwl)))

    l3y_o = getl3y_o()
    l3y_o['temporal'] = pd.to_datetime(l3y_o['temporal'])
    clwl = clwl.merge(l3y_o, how = 'left', indicator=True)
    clwl = clwl[clwl['_merge'] == 'left_only']
    clwl = clwl[["l3", "temporal"]]

    print("{} l3y matches left".format(len(clwl)))
    clwl.rename(columns = {'l3': 'gridId'}, inplace=True)
    clwl.to_sql('l3y_o', conn, if_exists='append', index = False, chunksize=1000)
    # print(clwl.head())

def l2y5_o_process(locations):
    clwl = locations[["l2", "temporal"]]
    clwl['datetime'] = clwl['temporal']
    clwl['temporal'] = clwl.apply(ut.year5snap, axis = 1)
    clwl['temporal'] = pd.to_datetime(clwl['temporal'])
    
    clwl = clwl[['l2', 'temporal']]
    clwl = clwl.drop_duplicates()

    print("{} l2y5 unique matches".format(len(clwl)))

    existing = getl2y5_o()
    existing['temporal'] = pd.to_datetime(existing['temporal'])
    clwl = clwl.merge(existing, how = 'left', indicator=True)
    clwl = clwl[clwl['_merge'] == 'left_only']
    clwl = clwl[["l2", "temporal"]]

    print("{} l2y5 matches left".format(len(clwl)))
    clwl.rename(columns = {'l2': 'gridId'}, inplace=True)
    clwl.to_sql('l2y5_o', conn, if_exists='append', index = False, chunksize=1000)
    # print(clwl.head())

def l1y5_o_process(locations):
    clwl = locations[["l1", "temporal"]]
    clwl['datetime'] = clwl['temporal']
    clwl['temporal'] = clwl.apply(ut.year5snap, axis = 1)
    clwl['temporal'] = pd.to_datetime(clwl['temporal'])
    
    clwl = clwl[['l1', 'temporal']]
    clwl = clwl.drop_duplicates()

    print("{} l1y5 unique matches".format(len(clwl)))

    existing = getl1y5_o()
    existing['temporal'] = pd.to_datetime(existing['temporal'])
    clwl = clwl.merge(existing, how = 'left', indicator=True)
    clwl = clwl[clwl['_merge'] == 'left_only']
    clwl = clwl[["l1", "temporal"]]

    print("{} l1y5 matches left".format(len(clwl)))
    clwl.rename(columns = {'l1': 'gridId'}, inplace=True)
    clwl.to_sql('l1y5_o', conn, if_exists='append', index = False, chunksize=1000)
    # print(clwl.head())

# %%
g1tog9 = getNewG1toG9()

# %%
for client_id in range(1, 376):
# for client_id in range(330, 358):
	
	print("Client: {}".format(client_id))
	query = """
	SELECT
		gridId AS l1,
		strftime ('%Y-%m-%d %H:00:00',
			datetime) AS temporal
	FROM
		locations
	WHERE
		client_id = {}
	""".format(client_id)
	cl = pd.read_sql(query, conn)
	print("{} locations found".format(len(cl)))
	cl.drop_duplicates(inplace=True)
	print("{} unique matches".format(len(cl)))

	clwl = cl.merge(g1tog9, how='left')
	if len(clwl) == 0:
		continue

	# print("l9h")
	# l9hprocess(clwl)
	print("l3y_o")
	l3y_o_process(clwl)
	# print("l2y5_o")
	# l2y5_o_process(clwl)
	# print("l1y5_o")
	# l1y5_o_process(clwl)

	# break
# Out:
# Client: 1
# 123968 locations found
# 19193 unique matches
# l3y_o
# 3497 l3y unique matches
# 3497 l3y matches left
# Client: 2
# 1185016 locations found
# 190445 unique matches
# l3y_o
# 29532 l3y unique matches
# 29420 l3y matches left
# Client: 3
# 2158747 locations found
# 293557 unique matches
# l3y_o
# 39201 l3y unique matches
# 38015 l3y matches left
# Client: 4
# 1668966 locations found
# 354135 unique matches
# l3y_o
# 63381 l3y unique matches
# 55020 l3y matches left
# Client: 5
# 1058614 locations found
# 192163 unique matches
# l3y_o
# 13377 l3y unique matches
# 6839 l3y matches left
# Client: 6
# 162550 locations found
# 26533 unique matches
# l3y_o
# 4062 l3y unique matches
# 3253 l3y matches left
# Client: 7
# 1265873 locations found
# 333736 unique matches
# l3y_o
# 32868 l3y unique matches
# 17727 l3y matches left
# Client: 8
# 1177083 locations found
# 281748 unique matches
# l3y_o
# 44614 l3y unique matches
# 34236 l3y matches left
# Client: 9
# 24100 locations found
# 5463 unique matches
# l3y_o
# 1283 l3y unique matches
# 532 l3y matches left
# Client: 10
# 1629 locations found
# 711 unique matches
# l3y_o
# 289 l3y unique matches
# 276 l3y matches left
# Client: 11
# 322601 locations found
# 60877 unique matches
# l3y_o
# 12152 l3y unique matches
# 11214 l3y matches left
# Client: 12
# 1591149 locations found
# 301855 unique matches
# l3y_o
# 51401 l3y unique matches
# 26838 l3y matches left
# Client: 13
# 1489192 locations found
# 279310 unique matches
# l3y_o
# 41659 l3y unique matches
# 20317 l3y matches left
# Client: 14
# 2799728 locations found
# 619389 unique matches
# l3y_o
# 106179 l3y unique matches
# 60836 l3y matches left
# Client: 15
# 118944 locations found
# 42266 unique matches
# l3y_o
# 9264 l3y unique matches
# 3443 l3y matches left
# Client: 16
# 1701534 locations found
# 256908 unique matches
# l3y_o
# 34401 l3y unique matches
# 18674 l3y matches left
# Client: 17
# 667819 locations found
# 153684 unique matches
# l3y_o
# 22555 l3y unique matches
# 8262 l3y matches left
# Client: 18
# 860628 locations found
# 139017 unique matches
# l3y_o
# 17843 l3y unique matches
# 6564 l3y matches left
# Client: 19
# 637453 locations found
# 301438 unique matches
# l3y_o
# 47159 l3y unique matches
# 18924 l3y matches left
# Client: 20
# 146309 locations found
# 13819 unique matches
# l3y_o
# 1780 l3y unique matches
# 1260 l3y matches left
# Client: 21
# 6363 locations found
# 5568 unique matches
# l3y_o
# 4001 l3y unique matches
# 1179 l3y matches left
# Client: 22
# 217704 locations found
# 9932 unique matches
# l3y_o
# 1540 l3y unique matches
# 1108 l3y matches left
# Client: 23
# 58208 locations found
# 6418 unique matches
# l3y_o
# 917 l3y unique matches
# 135 l3y matches left
# Client: 24
# 334697 locations found
# 58274 unique matches
# l3y_o
# 11216 l3y unique matches
# 7343 l3y matches left
# Client: 25
# 1684803 locations found
# 311703 unique matches
# l3y_o
# 45566 l3y unique matches
# 21202 l3y matches left
# Client: 26
# 685 locations found
# 166 unique matches
# l3y_o
# 88 l3y unique matches
# 2 l3y matches left
# Client: 27
# 341519 locations found
# 41629 unique matches
# l3y_o
# 3932 l3y unique matches
# 955 l3y matches left
# Client: 28
# 0 locations found
# 0 unique matches
# Client: 29
# 40250 locations found
# 32579 unique matches
# l3y_o
# 8856 l3y unique matches
# 3445 l3y matches left
# Client: 30
# 131652 locations found
# 27117 unique matches
# l3y_o
# 7613 l3y unique matches
# 3407 l3y matches left
# Client: 31
# 4402344 locations found
# 937771 unique matches
# l3y_o
# 136020 l3y unique matches
# 65885 l3y matches left
# Client: 32
# 1397800 locations found
# 196351 unique matches
# l3y_o
# 35114 l3y unique matches
# 21865 l3y matches left
# Client: 33
# 59321 locations found
# 11382 unique matches
# l3y_o
# 4125 l3y unique matches
# 1818 l3y matches left
# Client: 34
# 890837 locations found
# 195949 unique matches
# l3y_o
# 25517 l3y unique matches
# 14809 l3y matches left
# Client: 35
# 780574 locations found
# 110761 unique matches
# l3y_o
# 16565 l3y unique matches
# 9771 l3y matches left
# Client: 36
# 1395156 locations found
# 292553 unique matches
# l3y_o
# 24570 l3y unique matches
# 8982 l3y matches left
# Client: 37
# 2202593 locations found
# 528144 unique matches
# l3y_o
# 46778 l3y unique matches
# 33637 l3y matches left
# Client: 38
# 742646 locations found
# 157360 unique matches
# l3y_o
# 21829 l3y unique matches
# 6571 l3y matches left
# Client: 39
# 2033 locations found
# 458 unique matches
# l3y_o
# 183 l3y unique matches
# 144 l3y matches left
# Client: 40
# 1032669 locations found
# 205703 unique matches
# l3y_o
# 44143 l3y unique matches
# 10223 l3y matches left
# Client: 41
# 27287 locations found
# 22609 unique matches
# l3y_o
# 5658 l3y unique matches
# 818 l3y matches left
# Client: 42
# 1928242 locations found
# 231623 unique matches
# l3y_o
# 16858 l3y unique matches
# 7025 l3y matches left
# Client: 43
# 50976 locations found
# 5935 unique matches
# l3y_o
# 307 l3y unique matches
# 82 l3y matches left
# Client: 44
# 859853 locations found
# 180881 unique matches
# l3y_o
# 46932 l3y unique matches
# 23832 l3y matches left
# Client: 45
# 244065 locations found
# 55991 unique matches
# l3y_o
# 9271 l3y unique matches
# 1907 l3y matches left
# Client: 46
# 1643 locations found
# 1045 unique matches
# l3y_o
# 425 l3y unique matches
# 9 l3y matches left
# Client: 47
# 1042080 locations found
# 217175 unique matches
# l3y_o
# 28125 l3y unique matches
# 7887 l3y matches left
# Client: 48
# 1641904 locations found
# 245768 unique matches
# l3y_o
# 32710 l3y unique matches
# 9671 l3y matches left
# Client: 49
# 529734 locations found
# 179087 unique matches
# l3y_o
# 17717 l3y unique matches
# 5931 l3y matches left
# Client: 50
# 2790585 locations found
# 592511 unique matches
# l3y_o
# 66464 l3y unique matches
# 44447 l3y matches left
# Client: 51
# 2578860 locations found
# 710009 unique matches
# l3y_o
# 94488 l3y unique matches
# 61289 l3y matches left
# Client: 52
# 18822 locations found
# 6238 unique matches
# l3y_o
# 1596 l3y unique matches
# 352 l3y matches left
# Client: 53
# 63168 locations found
# 14687 unique matches
# l3y_o
# 4836 l3y unique matches
# 1211 l3y matches left
# Client: 54
# 33740 locations found
# 27640 unique matches
# l3y_o
# 9320 l3y unique matches
# 4411 l3y matches left
# Client: 55
# 637047 locations found
# 60546 unique matches
# l3y_o
# 4150 l3y unique matches
# 2220 l3y matches left
# Client: 56
# 255380 locations found
# 42268 unique matches
# l3y_o
# 4932 l3y unique matches
# 1073 l3y matches left
# Client: 57
# 1539362 locations found
# 288320 unique matches
# l3y_o
# 34002 l3y unique matches
# 7752 l3y matches left
# Client: 58
# 3822 locations found
# 3351 unique matches
# l3y_o
# 2226 l3y unique matches
# 1893 l3y matches left
# Client: 59
# 985925 locations found
# 278452 unique matches
# l3y_o
# 49213 l3y unique matches
# 31784 l3y matches left
# Client: 60
# 2099741 locations found
# 325827 unique matches
# l3y_o
# 42025 l3y unique matches
# 18258 l3y matches left
# Client: 61
# 642370 locations found
# 189608 unique matches
# l3y_o
# 37141 l3y unique matches
# 12231 l3y matches left
# Client: 62
# 195682 locations found
# 26638 unique matches
# l3y_o
# 1912 l3y unique matches
# 520 l3y matches left
# Client: 63
# 10508 locations found
# 2263 unique matches
# l3y_o
# 484 l3y unique matches
# 98 l3y matches left
# Client: 64
# 16685 locations found
# 4503 unique matches
# l3y_o
# 969 l3y unique matches
# 232 l3y matches left
# Client: 65
# 35858 locations found
# 13127 unique matches
# l3y_o
# 5712 l3y unique matches
# 2094 l3y matches left
# Client: 66
# 1471937 locations found
# 347262 unique matches
# l3y_o
# 68769 l3y unique matches
# 26333 l3y matches left
# Client: 67
# 46897 locations found
# 8764 unique matches
# l3y_o
# 4346 l3y unique matches
# 1326 l3y matches left
# Client: 68
# 12755 locations found
# 2124 unique matches
# l3y_o
# 214 l3y unique matches
# 36 l3y matches left
# Client: 69
# 372889 locations found
# 40686 unique matches
# l3y_o
# 10401 l3y unique matches
# 3185 l3y matches left
# Client: 70
# 164896 locations found
# 51509 unique matches
# l3y_o
# 7517 l3y unique matches
# 1505 l3y matches left
# Client: 71
# 755650 locations found
# 220794 unique matches
# l3y_o
# 35927 l3y unique matches
# 5370 l3y matches left
# Client: 72
# 36516 locations found
# 31003 unique matches
# l3y_o
# 7537 l3y unique matches
# 1525 l3y matches left
# Client: 73
# 1 locations found
# 1 unique matches
# l3y_o
# 1 l3y unique matches
# 1 l3y matches left
# Client: 74
# 5939 locations found
# 5302 unique matches
# l3y_o
# 1379 l3y unique matches
# 209 l3y matches left
# Client: 75
# 104 locations found
# 70 unique matches
# l3y_o
# 37 l3y unique matches
# 17 l3y matches left
# Client: 76
# 334295 locations found
# 80104 unique matches
# l3y_o
# 15466 l3y unique matches
# 3089 l3y matches left
# Client: 77
# 13158 locations found
# 9746 unique matches
# l3y_o
# 3358 l3y unique matches
# 1338 l3y matches left
# Client: 78
# 1422787 locations found
# 199175 unique matches
# l3y_o
# 39994 l3y unique matches
# 14373 l3y matches left
# Client: 79
# 812721 locations found
# 105440 unique matches
# l3y_o
# 19933 l3y unique matches
# 7125 l3y matches left
# Client: 80
# 2163451 locations found
# 262818 unique matches
# l3y_o
# 34150 l3y unique matches
# 9244 l3y matches left
# Client: 81
# 1683407 locations found
# 332339 unique matches
# l3y_o
# 22175 l3y unique matches
# 7358 l3y matches left
# Client: 82
# 2796239 locations found
# 335364 unique matches
# l3y_o
# 43989 l3y unique matches
# 10734 l3y matches left
# Client: 83
# 2665 locations found
# 2292 unique matches
# l3y_o
# 552 l3y unique matches
# 44 l3y matches left
# Client: 84
# 482773 locations found
# 115818 unique matches
# l3y_o
# 7686 l3y unique matches
# 2257 l3y matches left
# Client: 85
# 368498 locations found
# 59808 unique matches
# l3y_o
# 8169 l3y unique matches
# 2022 l3y matches left
# Client: 86
# 228913 locations found
# 24063 unique matches
# l3y_o
# 1658 l3y unique matches
# 1075 l3y matches left
# Client: 87
# 2181 locations found
# 403 unique matches
# l3y_o
# 205 l3y unique matches
# 10 l3y matches left
# Client: 88
# 1577562 locations found
# 319175 unique matches
# l3y_o
# 42217 l3y unique matches
# 13378 l3y matches left
# Client: 89
# 634803 locations found
# 135830 unique matches
# l3y_o
# 23279 l3y unique matches
# 4901 l3y matches left
# Client: 90
# 136941 locations found
# 56463 unique matches
# l3y_o
# 6607 l3y unique matches
# 1176 l3y matches left
# Client: 91
# 108969 locations found
# 32315 unique matches
# l3y_o
# 5691 l3y unique matches
# 1050 l3y matches left
# Client: 92
# 0 locations found
# 0 unique matches
# Client: 93
# 398581 locations found
# 126334 unique matches
# l3y_o
# 20329 l3y unique matches
# 3123 l3y matches left
# Client: 94
# 6317 locations found
# 5406 unique matches
# l3y_o
# 1887 l3y unique matches
# 298 l3y matches left
# Client: 95
# 1299148 locations found
# 324407 unique matches
# l3y_o
# 54791 l3y unique matches
# 13542 l3y matches left
# Client: 96
# 1562364 locations found
# 328513 unique matches
# l3y_o
# 51643 l3y unique matches
# 14662 l3y matches left
# Client: 97
# 1411787 locations found
# 307298 unique matches
# l3y_o
# 27637 l3y unique matches
# 6888 l3y matches left
# Client: 98
# 1110005 locations found
# 222452 unique matches
# l3y_o
# 32655 l3y unique matches
# 13041 l3y matches left
# Client: 99
# 653302 locations found
# 190687 unique matches
# l3y_o
# 46959 l3y unique matches
# 18008 l3y matches left
# Client: 100
# 1104657 locations found
# 171128 unique matches
# l3y_o
# 10608 l3y unique matches
# 1781 l3y matches left
# Client: 101
# 1100377 locations found
# 212384 unique matches
# l3y_o
# 28854 l3y unique matches
# 3880 l3y matches left
# Client: 102
# 11136 locations found
# 4195 unique matches
# l3y_o
# 1246 l3y unique matches
# 218 l3y matches left
# Client: 103
# 484 locations found
# 123 unique matches
# l3y_o
# 53 l3y unique matches
# 9 l3y matches left
# Client: 104
# 963347 locations found
# 91046 unique matches
# l3y_o
# 12379 l3y unique matches
# 2305 l3y matches left
# Client: 105
# 1587542 locations found
# 215707 unique matches
# l3y_o
# 22172 l3y unique matches
# 1958 l3y matches left
# Client: 106
# 512296 locations found
# 148168 unique matches
# l3y_o
# 46942 l3y unique matches
# 11400 l3y matches left
# Client: 107
# 1 locations found
# 1 unique matches
# l3y_o
# 1 l3y unique matches
# 1 l3y matches left
# Client: 108
# 793710 locations found
# 115950 unique matches
# l3y_o
# 20571 l3y unique matches
# 5726 l3y matches left
# Client: 109
# 9820 locations found
# 6505 unique matches
# l3y_o
# 2977 l3y unique matches
# 1473 l3y matches left
# Client: 110
# 2336628 locations found
# 381067 unique matches
# l3y_o
# 60015 l3y unique matches
# 23079 l3y matches left
# Client: 111
# 2272 locations found
# 1904 unique matches
# l3y_o
# 711 l3y unique matches
# 24 l3y matches left
# Client: 112
# 175768 locations found
# 93818 unique matches
# l3y_o
# 15199 l3y unique matches
# 5377 l3y matches left
# Client: 113
# 25033 locations found
# 20912 unique matches
# l3y_o
# 6170 l3y unique matches
# 4078 l3y matches left
# Client: 114
# 2313240 locations found
# 449923 unique matches
# l3y_o
# 75537 l3y unique matches
# 18149 l3y matches left
# Client: 115
# 1486220 locations found
# 300815 unique matches
# l3y_o
# 53735 l3y unique matches
# 1 l3y matches left
# Client: 116
# 1942491 locations found
# 401230 unique matches
# l3y_o
# 64307 l3y unique matches
# 12714 l3y matches left
# Client: 117
# 1355402 locations found
# 249504 unique matches
# l3y_o
# 41262 l3y unique matches
# 0 l3y matches left
# Client: 118
# 585308 locations found
# 138801 unique matches
# l3y_o
# 20076 l3y unique matches
# 0 l3y matches left
# Client: 119
# 723280 locations found
# 118980 unique matches
# l3y_o
# 15273 l3y unique matches
# 0 l3y matches left
# Client: 120
# 1360 locations found
# 1183 unique matches
# l3y_o
# 344 l3y unique matches
# 0 l3y matches left
# Client: 121
# 1481746 locations found
# 217429 unique matches
# l3y_o
# 39273 l3y unique matches
# 11923 l3y matches left
# Client: 122
# 45312 locations found
# 4902 unique matches
# l3y_o
# 664 l3y unique matches
# 85 l3y matches left
# Client: 123
# 22349 locations found
# 3881 unique matches
# l3y_o
# 563 l3y unique matches
# 0 l3y matches left
# Client: 124
# 451185 locations found
# 130398 unique matches
# l3y_o
# 37189 l3y unique matches
# 5637 l3y matches left
# Client: 125
# 0 locations found
# 0 unique matches
# Client: 126
# 937584 locations found
# 172604 unique matches
# l3y_o
# 38055 l3y unique matches
# 0 l3y matches left
# Client: 127
# 12700 locations found
# 3799 unique matches
# l3y_o
# 803 l3y unique matches
# 32 l3y matches left
# Client: 128
# 63168 locations found
# 14688 unique matches
# l3y_o
# 4836 l3y unique matches
# 0 l3y matches left
# Client: 129
# 696612 locations found
# 211125 unique matches
# l3y_o
# 50590 l3y unique matches
# 9750 l3y matches left
# Client: 130
# 3822 locations found
# 3351 unique matches
# l3y_o
# 2226 l3y unique matches
# 0 l3y matches left
# Client: 131
# 3822 locations found
# 3351 unique matches
# l3y_o
# 2226 l3y unique matches
# 0 l3y matches left
# Client: 132
# 690785 locations found
# 141832 unique matches
# l3y_o
# 19295 l3y unique matches
# 0 l3y matches left
# Client: 133
# 1373960 locations found
# 333698 unique matches
# l3y_o
# 50336 l3y unique matches
# 6082 l3y matches left
# Client: 134
# 1062168 locations found
# 161020 unique matches
# l3y_o
# 18669 l3y unique matches
# 1879 l3y matches left
# Client: 135
# 190413 locations found
# 40391 unique matches
# l3y_o
# 5031 l3y unique matches
# 832 l3y matches left
# Client: 136
# 192455 locations found
# 30744 unique matches
# l3y_o
# 3929 l3y unique matches
# 1543 l3y matches left
# Client: 137
# 542901 locations found
# 109124 unique matches
# l3y_o
# 16927 l3y unique matches
# 1247 l3y matches left
# Client: 138
# 35858 locations found
# 13127 unique matches
# l3y_o
# 5712 l3y unique matches
# 0 l3y matches left
# Client: 139
# 1381457 locations found
# 324470 unique matches
# l3y_o
# 61350 l3y unique matches
# 15 l3y matches left
# Client: 140
# 1562 locations found
# 1245 unique matches
# l3y_o
# 580 l3y unique matches
# 40 l3y matches left
# Client: 141
# 372889 locations found
# 40685 unique matches
# l3y_o
# 10402 l3y unique matches
# 1 l3y matches left
# Client: 142
# 109338 locations found
# 14065 unique matches
# l3y_o
# 2258 l3y unique matches
# 597 l3y matches left
# Client: 143
# 686725 locations found
# 194652 unique matches
# l3y_o
# 31413 l3y unique matches
# 0 l3y matches left
# Client: 144
# 36516 locations found
# 31003 unique matches
# l3y_o
# 7537 l3y unique matches
# 0 l3y matches left
# Client: 145
# 5953 locations found
# 5312 unique matches
# l3y_o
# 1312 l3y unique matches
# 0 l3y matches left
# Client: 146
# 13158 locations found
# 9746 unique matches
# l3y_o
# 3358 l3y unique matches
# 0 l3y matches left
# Client: 147
# 241595 locations found
# 52196 unique matches
# l3y_o
# 14868 l3y unique matches
# 2356 l3y matches left
# Client: 148
# 139255 locations found
# 51369 unique matches
# l3y_o
# 26826 l3y unique matches
# 3501 l3y matches left
# Client: 149
# 2665 locations found
# 2292 unique matches
# l3y_o
# 552 l3y unique matches
# 0 l3y matches left
# Client: 150
# 1937003 locations found
# 329585 unique matches
# l3y_o
# 57992 l3y unique matches
# 15512 l3y matches left
# Client: 151
# 525 locations found
# 480 unique matches
# l3y_o
# 234 l3y unique matches
# 4 l3y matches left
# Client: 152
# 53614 locations found
# 10404 unique matches
# l3y_o
# 3219 l3y unique matches
# 612 l3y matches left
# Client: 153
# 61743 locations found
# 12093 unique matches
# l3y_o
# 1549 l3y unique matches
# 116 l3y matches left
# Client: 154
# 2689955 locations found
# 532370 unique matches
# l3y_o
# 65708 l3y unique matches
# 8345 l3y matches left
# Client: 155
# 2893054 locations found
# 362982 unique matches
# l3y_o
# 43395 l3y unique matches
# 16274 l3y matches left
# Client: 156
# 136941 locations found
# 56463 unique matches
# l3y_o
# 6607 l3y unique matches
# 0 l3y matches left
# Client: 157
# 624397 locations found
# 143859 unique matches
# l3y_o
# 24323 l3y unique matches
# 3089 l3y matches left
# Client: 158
# 728513 locations found
# 221378 unique matches
# l3y_o
# 32202 l3y unique matches
# 1926 l3y matches left
# Client: 159
# 842651 locations found
# 208562 unique matches
# l3y_o
# 26523 l3y unique matches
# 1412 l3y matches left
# Client: 160
# 1445253 locations found
# 175197 unique matches
# l3y_o
# 18888 l3y unique matches
# 921 l3y matches left
# Client: 161
# 2816464 locations found
# 333360 unique matches
# l3y_o
# 20936 l3y unique matches
# 1304 l3y matches left
# Client: 162
# 6317 locations found
# 5406 unique matches
# l3y_o
# 1887 l3y unique matches
# 0 l3y matches left
# Client: 163
# 213239 locations found
# 48044 unique matches
# l3y_o
# 9097 l3y unique matches
# 1431 l3y matches left
# Client: 164
# 2047179 locations found
# 384486 unique matches
# l3y_o
# 63228 l3y unique matches
# 15207 l3y matches left
# Client: 165
# 4565 locations found
# 3770 unique matches
# l3y_o
# 950 l3y unique matches
# 90 l3y matches left
# Client: 166
# 225834 locations found
# 85847 unique matches
# l3y_o
# 21329 l3y unique matches
# 4102 l3y matches left
# Client: 167
# 304182 locations found
# 69721 unique matches
# l3y_o
# 12220 l3y unique matches
# 0 l3y matches left
# Client: 168
# 369055 locations found
# 57469 unique matches
# l3y_o
# 7502 l3y unique matches
# 989 l3y matches left
# Client: 169
# 324249 locations found
# 70809 unique matches
# l3y_o
# 13350 l3y unique matches
# 1436 l3y matches left
# Client: 170
# 244007 locations found
# 44676 unique matches
# l3y_o
# 8099 l3y unique matches
# 1857 l3y matches left
# Client: 171
# 723232 locations found
# 238646 unique matches
# l3y_o
# 28173 l3y unique matches
# 5331 l3y matches left
# Client: 172
# 566208 locations found
# 149775 unique matches
# l3y_o
# 33233 l3y unique matches
# 0 l3y matches left
# Client: 173
# 28075 locations found
# 22703 unique matches
# l3y_o
# 7370 l3y unique matches
# 462 l3y matches left
# Client: 174
# 835339 locations found
# 148669 unique matches
# l3y_o
# 27270 l3y unique matches
# 2005 l3y matches left
# Client: 175
# 2903 locations found
# 2080 unique matches
# l3y_o
# 622 l3y unique matches
# 5 l3y matches left
# Client: 176
# 1991283 locations found
# 299623 unique matches
# l3y_o
# 42026 l3y unique matches
# 11006 l3y matches left
# Client: 177
# 319981 locations found
# 64892 unique matches
# l3y_o
# 7933 l3y unique matches
# 803 l3y matches left
# Client: 178
# 6886 locations found
# 6089 unique matches
# l3y_o
# 2408 l3y unique matches
# 338 l3y matches left
# Client: 179
# 856981 locations found
# 282213 unique matches
# l3y_o
# 78541 l3y unique matches
# 34507 l3y matches left
# Client: 180
# 1841640 locations found
# 383529 unique matches
# l3y_o
# 42259 l3y unique matches
# 30304 l3y matches left
# Client: 181
# 916058 locations found
# 221597 unique matches
# l3y_o
# 26382 l3y unique matches
# 5412 l3y matches left
# Client: 182
# 2564556 locations found
# 584527 unique matches
# l3y_o
# 89931 l3y unique matches
# 9430 l3y matches left
# Client: 183
# 1427 locations found
# 97 unique matches
# l3y_o
# 8 l3y unique matches
# 8 l3y matches left
# Client: 184
# 36395 locations found
# 5899 unique matches
# l3y_o
# 1035 l3y unique matches
# 505 l3y matches left
# Client: 185
# 675224 locations found
# 115371 unique matches
# l3y_o
# 13480 l3y unique matches
# 3481 l3y matches left
# Client: 186
# 3043821 locations found
# 849326 unique matches
# l3y_o
# 44805 l3y unique matches
# 4315 l3y matches left
# Client: 187
# 0 locations found
# 0 unique matches
# Client: 188
# 1550996 locations found
# 362292 unique matches
# l3y_o
# 49889 l3y unique matches
# 6350 l3y matches left
# Client: 189
# 1778856 locations found
# 352992 unique matches
# l3y_o
# 49043 l3y unique matches
# 8975 l3y matches left
# Client: 190
# 0 locations found
# 0 unique matches
# Client: 191
# 197728 locations found
# 39590 unique matches
# l3y_o
# 6034 l3y unique matches
# 645 l3y matches left
# Client: 192
# 37397 locations found
# 7313 unique matches
# l3y_o
# 1360 l3y unique matches
# 1172 l3y matches left
# Client: 193
# 1699119 locations found
# 381706 unique matches
# l3y_o
# 49321 l3y unique matches
# 35155 l3y matches left
# Client: 194
# 2181541 locations found
# 495844 unique matches
# l3y_o
# 67481 l3y unique matches
# 16698 l3y matches left
# Client: 195
# 32947 locations found
# 6843 unique matches
# l3y_o
# 2360 l3y unique matches
# 1107 l3y matches left
# Client: 196
# 1311785 locations found
# 266951 unique matches
# l3y_o
# 16177 l3y unique matches
# 2077 l3y matches left
# Client: 197
# 658949 locations found
# 97589 unique matches
# l3y_o
# 7571 l3y unique matches
# 7095 l3y matches left
# Client: 198
# 676202 locations found
# 156173 unique matches
# l3y_o
# 18453 l3y unique matches
# 14126 l3y matches left
# Client: 199
# 65427 locations found
# 51712 unique matches
# l3y_o
# 21893 l3y unique matches
# 5855 l3y matches left
# Client: 200
# 44799 locations found
# 27439 unique matches
# l3y_o
# 10885 l3y unique matches
# 3899 l3y matches left
# Client: 201
# 20417 locations found
# 12672 unique matches
# l3y_o
# 4701 l3y unique matches
# 1053 l3y matches left
# Client: 202
# 14372 locations found
# 11485 unique matches
# l3y_o
# 2701 l3y unique matches
# 632 l3y matches left
# Client: 203
# 2025502 locations found
# 289075 unique matches
# l3y_o
# 20805 l3y unique matches
# 9324 l3y matches left
# Client: 204
# 0 locations found
# 0 unique matches
# Client: 205
# 40619 locations found
# 34685 unique matches
# l3y_o
# 8187 l3y unique matches
# 610 l3y matches left
# Client: 206
# 354047 locations found
# 77588 unique matches
# l3y_o
# 19316 l3y unique matches
# 1974 l3y matches left
# Client: 207
# 1958075 locations found
# 408187 unique matches
# l3y_o
# 83114 l3y unique matches
# 15461 l3y matches left
# Client: 208
# 3121817 locations found
# 366118 unique matches
# l3y_o
# 33262 l3y unique matches
# 12152 l3y matches left
# Client: 209
# 23241 locations found
# 5496 unique matches
# l3y_o
# 1554 l3y unique matches
# 26 l3y matches left
# Client: 210
# 493035 locations found
# 102550 unique matches
# l3y_o
# 5201 l3y unique matches
# 2829 l3y matches left
# Client: 211
# 827767 locations found
# 187320 unique matches
# l3y_o
# 30527 l3y unique matches
# 18592 l3y matches left
# Client: 212
# 3363 locations found
# 826 unique matches
# l3y_o
# 11 l3y unique matches
# 11 l3y matches left
# Client: 213
# 105468 locations found
# 59547 unique matches
# l3y_o
# 13599 l3y unique matches
# 9431 l3y matches left
# Client: 214
# 2375221 locations found
# 284907 unique matches
# l3y_o
# 21911 l3y unique matches
# 13375 l3y matches left
# Client: 215
# 89100 locations found
# 15092 unique matches
# l3y_o
# 3787 l3y unique matches
# 321 l3y matches left
# Client: 216
# 2481339 locations found
# 403016 unique matches
# l3y_o
# 51199 l3y unique matches
# 10486 l3y matches left
# Client: 217
# 1736901 locations found
# 182697 unique matches
# l3y_o
# 12712 l3y unique matches
# 2849 l3y matches left
# Client: 218
# 567802 locations found
# 59668 unique matches
# l3y_o
# 10078 l3y unique matches
# 5301 l3y matches left
# Client: 219
# 516767 locations found
# 86827 unique matches
# l3y_o
# 10253 l3y unique matches
# 2681 l3y matches left
# Client: 220
# 32026 locations found
# 11311 unique matches
# l3y_o
# 3323 l3y unique matches
# 1662 l3y matches left
# Client: 221
# 826007 locations found
# 211017 unique matches
# l3y_o
# 20204 l3y unique matches
# 1151 l3y matches left
# Client: 222
# 0 locations found
# 0 unique matches
# Client: 223
# 220983 locations found
# 40821 unique matches
# l3y_o
# 4488 l3y unique matches
# 279 l3y matches left
# Client: 224
# 1061243 locations found
# 235723 unique matches
# l3y_o
# 20325 l3y unique matches
# 10616 l3y matches left
# Client: 225
# 424008 locations found
# 119691 unique matches
# l3y_o
# 4843 l3y unique matches
# 1921 l3y matches left
# Client: 226
# 0 locations found
# 0 unique matches
# Client: 227
# 0 locations found
# 0 unique matches
# Client: 228
# 57547 locations found
# 9801 unique matches
# l3y_o
# 1762 l3y unique matches
# 874 l3y matches left
# Client: 229
# 2241932 locations found
# 331688 unique matches
# l3y_o
# 58446 l3y unique matches
# 9731 l3y matches left
# Client: 230
# 1879360 locations found
# 355489 unique matches
# l3y_o
# 48253 l3y unique matches
# 8154 l3y matches left
# Client: 231
# 0 locations found
# 0 unique matches
# Client: 232
# 648962 locations found
# 179048 unique matches
# l3y_o
# 26389 l3y unique matches
# 5708 l3y matches left
# Client: 233
# 468314 locations found
# 129626 unique matches
# l3y_o
# 16685 l3y unique matches
# 1869 l3y matches left
# Client: 234
# 2649375 locations found
# 429446 unique matches
# l3y_o
# 76488 l3y unique matches
# 22450 l3y matches left
# Client: 235
# 39840 locations found
# 24480 unique matches
# l3y_o
# 7137 l3y unique matches
# 445 l3y matches left
# Client: 236
# 223014 locations found
# 26301 unique matches
# l3y_o
# 4614 l3y unique matches
# 3050 l3y matches left
# Client: 237
# 1549493 locations found
# 275533 unique matches
# l3y_o
# 34361 l3y unique matches
# 8190 l3y matches left
# Client: 238
# 176413 locations found
# 44028 unique matches
# l3y_o
# 5355 l3y unique matches
# 3281 l3y matches left
# Client: 239
# 0 locations found
# 0 unique matches
# Client: 240
# 12553 locations found
# 6909 unique matches
# l3y_o
# 2539 l3y unique matches
# 1277 l3y matches left
# Client: 241
# 956237 locations found
# 187051 unique matches
# l3y_o
# 23167 l3y unique matches
# 3079 l3y matches left
# Client: 242
# 534468 locations found
# 107607 unique matches
# l3y_o
# 22519 l3y unique matches
# 5972 l3y matches left
# Client: 243
# 177625 locations found
# 63223 unique matches
# l3y_o
# 25078 l3y unique matches
# 7438 l3y matches left
# Client: 244
# 5120417 locations found
# 710018 unique matches
# l3y_o
# 72246 l3y unique matches
# 54140 l3y matches left
# Client: 245
# 358956 locations found
# 93396 unique matches
# l3y_o
# 40837 l3y unique matches
# 6684 l3y matches left
# Client: 246
# 1850699 locations found
# 447541 unique matches
# l3y_o
# 77429 l3y unique matches
# 10526 l3y matches left
# Client: 247
# 44001 locations found
# 11777 unique matches
# l3y_o
# 3816 l3y unique matches
# 282 l3y matches left
# Client: 248
# 1147270 locations found
# 168821 unique matches
# l3y_o
# 26105 l3y unique matches
# 4294 l3y matches left
# Client: 249
# 248128 locations found
# 18121 unique matches
# l3y_o
# 2060 l3y unique matches
# 1420 l3y matches left
# Client: 250
# 1032393 locations found
# 226709 unique matches
# l3y_o
# 26128 l3y unique matches
# 3592 l3y matches left
# Client: 251
# 1272292 locations found
# 329482 unique matches
# l3y_o
# 36652 l3y unique matches
# 1690 l3y matches left
# Client: 252
# 391971 locations found
# 80648 unique matches
# l3y_o
# 9772 l3y unique matches
# 697 l3y matches left
# Client: 253
# 8528 locations found
# 6337 unique matches
# l3y_o
# 812 l3y unique matches
# 95 l3y matches left
# Client: 254
# 256767 locations found
# 25044 unique matches
# l3y_o
# 2433 l3y unique matches
# 1624 l3y matches left
# Client: 255
# 399336 locations found
# 89965 unique matches
# l3y_o
# 16996 l3y unique matches
# 15634 l3y matches left
# Client: 256
# 0 locations found
# 0 unique matches
# Client: 257
# 69848 locations found
# 7920 unique matches
# l3y_o
# 463 l3y unique matches
# 12 l3y matches left
# Client: 258
# 407 locations found
# 74 unique matches
# l3y_o
# 36 l3y unique matches
# 5 l3y matches left
# Client: 259
# 1226850 locations found
# 213804 unique matches
# l3y_o
# 35250 l3y unique matches
# 12856 l3y matches left
# Client: 260
# 7031 locations found
# 6124 unique matches
# l3y_o
# 1208 l3y unique matches
# 572 l3y matches left
# Client: 261
# 15174 locations found
# 4667 unique matches
# l3y_o
# 1049 l3y unique matches
# 37 l3y matches left
# Client: 262
# 1257281 locations found
# 248147 unique matches
# l3y_o
# 39362 l3y unique matches
# 5048 l3y matches left
# Client: 263
# 1292201 locations found
# 247249 unique matches
# l3y_o
# 33586 l3y unique matches
# 13624 l3y matches left
# Client: 264
# 1334682 locations found
# 248601 unique matches
# l3y_o
# 28329 l3y unique matches
# 5853 l3y matches left
# Client: 265
# 846118 locations found
# 172032 unique matches
# l3y_o
# 19313 l3y unique matches
# 8213 l3y matches left
# Client: 266
# 1111662 locations found
# 269972 unique matches
# l3y_o
# 29143 l3y unique matches
# 14529 l3y matches left
# Client: 267
# 0 locations found
# 0 unique matches
# Client: 268
# 2332500 locations found
# 311023 unique matches
# l3y_o
# 35431 l3y unique matches
# 9707 l3y matches left
# Client: 269
# 1147193 locations found
# 55416 unique matches
# l3y_o
# 2247 l3y unique matches
# 106 l3y matches left
# Client: 270
# 0 locations found
# 0 unique matches
# Client: 271
# 423909 locations found
# 109203 unique matches
# l3y_o
# 21851 l3y unique matches
# 3197 l3y matches left
# Client: 272
# 1602601 locations found
# 185411 unique matches
# l3y_o
# 20232 l3y unique matches
# 11226 l3y matches left
# Client: 273
# 1056038 locations found
# 314759 unique matches
# l3y_o
# 54425 l3y unique matches
# 4679 l3y matches left
# Client: 274
# 0 locations found
# 0 unique matches
# Client: 275
# 1978379 locations found
# 344714 unique matches
# l3y_o
# 54135 l3y unique matches
# 13619 l3y matches left
# Client: 276
# 2796597 locations found
# 332858 unique matches
# l3y_o
# 53626 l3y unique matches
# 7656 l3y matches left
# Client: 277
# 187271 locations found
# 51527 unique matches
# l3y_o
# 7641 l3y unique matches
# 331 l3y matches left
# Client: 278
# 612470 locations found
# 152885 unique matches
# l3y_o
# 8568 l3y unique matches
# 996 l3y matches left
# Client: 279
# 3049 locations found
# 2490 unique matches
# l3y_o
# 785 l3y unique matches
# 321 l3y matches left
# Client: 280
# 2070146 locations found
# 359083 unique matches
# l3y_o
# 32136 l3y unique matches
# 2354 l3y matches left
# Client: 281
# 0 locations found
# 0 unique matches
# Client: 282
# 701952 locations found
# 91743 unique matches
# l3y_o
# 16896 l3y unique matches
# 2701 l3y matches left
# Client: 283
# 938430 locations found
# 198996 unique matches
# l3y_o
# 38888 l3y unique matches
# 6958 l3y matches left
# Client: 284
# 1051603 locations found
# 185759 unique matches
# l3y_o
# 26177 l3y unique matches
# 6007 l3y matches left
# Client: 285
# 1038345 locations found
# 233971 unique matches
# l3y_o
# 48776 l3y unique matches
# 6067 l3y matches left
# Client: 286
# 142753 locations found
# 44979 unique matches
# l3y_o
# 8027 l3y unique matches
# 1801 l3y matches left
# Client: 287
# 0 locations found
# 0 unique matches
# Client: 288
# 1176151 locations found
# 240615 unique matches
# l3y_o
# 39995 l3y unique matches
# 7262 l3y matches left
# Client: 289
# 2335815 locations found
# 250348 unique matches
# l3y_o
# 35139 l3y unique matches
# 4412 l3y matches left
# Client: 290
# 402555 locations found
# 150055 unique matches
# l3y_o
# 28793 l3y unique matches
# 2287 l3y matches left
# Client: 291
# 2550373 locations found
# 287915 unique matches
# l3y_o
# 52727 l3y unique matches
# 10973 l3y matches left
# Client: 292
# 2189771 locations found
# 262674 unique matches
# l3y_o
# 26628 l3y unique matches
# 3773 l3y matches left
# Client: 293
# 96130 locations found
# 21375 unique matches
# l3y_o
# 9981 l3y unique matches
# 1341 l3y matches left
# Client: 294
# 1122339 locations found
# 245425 unique matches
# l3y_o
# 45585 l3y unique matches
# 4730 l3y matches left
# Client: 295
# 99446 locations found
# 25389 unique matches
# l3y_o
# 3024 l3y unique matches
# 748 l3y matches left
# Client: 296
# 100581 locations found
# 82217 unique matches
# l3y_o
# 15816 l3y unique matches
# 3550 l3y matches left
# Client: 297
# 143421 locations found
# 20887 unique matches
# l3y_o
# 3626 l3y unique matches
# 442 l3y matches left
# Client: 298
# 524277 locations found
# 78472 unique matches
# l3y_o
# 6834 l3y unique matches
# 1642 l3y matches left
# Client: 299
# 10953 locations found
# 10195 unique matches
# l3y_o
# 3099 l3y unique matches
# 809 l3y matches left
# Client: 300
# 595544 locations found
# 133827 unique matches
# l3y_o
# 19755 l3y unique matches
# 2959 l3y matches left
# Client: 301
# 2224374 locations found
# 254724 unique matches
# l3y_o
# 38805 l3y unique matches
# 7685 l3y matches left
# Client: 302
# 2444078 locations found
# 283223 unique matches
# l3y_o
# 22797 l3y unique matches
# 1860 l3y matches left
# Client: 303
# 186 locations found
# 168 unique matches
# l3y_o
# 113 l3y unique matches
# 5 l3y matches left
# Client: 304
# 248120 locations found
# 61960 unique matches
# l3y_o
# 14203 l3y unique matches
# 965 l3y matches left
# Client: 305
# 746906 locations found
# 144605 unique matches
# l3y_o
# 18254 l3y unique matches
# 889 l3y matches left
# Client: 306
# 31242 locations found
# 7792 unique matches
# l3y_o
# 1613 l3y unique matches
# 1489 l3y matches left
# Client: 307
# 740625 locations found
# 181922 unique matches
# l3y_o
# 14213 l3y unique matches
# 5246 l3y matches left
# Client: 308
# 30555 locations found
# 23563 unique matches
# l3y_o
# 5630 l3y unique matches
# 1906 l3y matches left
# Client: 309
# 376677 locations found
# 79676 unique matches
# l3y_o
# 12030 l3y unique matches
# 832 l3y matches left
# Client: 310
# 0 locations found
# 0 unique matches
# Client: 311
# 684879 locations found
# 116834 unique matches
# l3y_o
# 8217 l3y unique matches
# 1338 l3y matches left
# Client: 312
# 11502 locations found
# 6203 unique matches
# l3y_o
# 3426 l3y unique matches
# 2849 l3y matches left
# Client: 313
# 558354 locations found
# 154505 unique matches
# l3y_o
# 20002 l3y unique matches
# 6139 l3y matches left
# Client: 314
# 31206 locations found
# 12856 unique matches
# l3y_o
# 2384 l3y unique matches
# 1912 l3y matches left
# Client: 315
# 0 locations found
# 0 unique matches
# Client: 316
# 1645470 locations found
# 277432 unique matches
# l3y_o
# 30508 l3y unique matches
# 14879 l3y matches left
# Client: 317
# 3231148 locations found
# 590963 unique matches
# l3y_o
# 59148 l3y unique matches
# 28570 l3y matches left
# Client: 318
# 596434 locations found
# 223738 unique matches
# l3y_o
# 30689 l3y unique matches
# 11390 l3y matches left
# Client: 319
# 140347 locations found
# 77288 unique matches
# l3y_o
# 9998 l3y unique matches
# 3413 l3y matches left
# Client: 320
# 2015023 locations found
# 351783 unique matches
# l3y_o
# 58525 l3y unique matches
# 22605 l3y matches left
# Client: 321
# 2374045 locations found
# 191083 unique matches
# l3y_o
# 26202 l3y unique matches
# 11449 l3y matches left
# Client: 322
# 2452583 locations found
# 491686 unique matches
# l3y_o
# 91057 l3y unique matches
# 36422 l3y matches left
# Client: 323
# 1091052 locations found
# 201477 unique matches
# l3y_o
# 30859 l3y unique matches
# 19939 l3y matches left
# Client: 324
# 2861473 locations found
# 405496 unique matches
# l3y_o
# 60936 l3y unique matches
# 23469 l3y matches left
# Client: 325
# 3070984 locations found
# 553544 unique matches
# l3y_o
# 48094 l3y unique matches
# 11349 l3y matches left
# Client: 326
# 742810 locations found
# 107214 unique matches
# l3y_o
# 8776 l3y unique matches
# 938 l3y matches left
# Client: 327
# 1537051 locations found
# 270223 unique matches
# l3y_o
# 28144 l3y unique matches
# 9732 l3y matches left
# Client: 328
# 46215 locations found
# 5527 unique matches
# l3y_o
# 402 l3y unique matches
# 224 l3y matches left
# Client: 329
# 1202946 locations found
# 122175 unique matches
# l3y_o
# 2937 l3y unique matches
# 228 l3y matches left
# Client: 330
# 815538 locations found
# 199694 unique matches
# l3y_o
# 38706 l3y unique matches
# 9672 l3y matches left
# Client: 331
# 29951 locations found
# 10473 unique matches
# l3y_o
# 1931 l3y unique matches
# 1419 l3y matches left
# Client: 332
# 151449 locations found
# 31316 unique matches
# l3y_o
# 5272 l3y unique matches
# 1131 l3y matches left
# Client: 333
# 7174 locations found
# 1945 unique matches
# l3y_o
# 446 l3y unique matches
# 291 l3y matches left
# Client: 334
# 4025 locations found
# 2597 unique matches
# l3y_o
# 1738 l3y unique matches
# 150 l3y matches left
# Client: 335
# 4603 locations found
# 1104 unique matches
# l3y_o
# 254 l3y unique matches
# 95 l3y matches left
# Client: 336
# 352745 locations found
# 97412 unique matches
# l3y_o
# 12973 l3y unique matches
# 5790 l3y matches left
# Client: 337
# 65482 locations found
# 15517 unique matches
# l3y_o
# 3899 l3y unique matches
# 3179 l3y matches left
# Client: 338
# 1605956 locations found
# 237011 unique matches
# l3y_o
# 28310 l3y unique matches
# 7033 l3y matches left
# Client: 339
# 97034 locations found
# 46815 unique matches
# l3y_o
# 8361 l3y unique matches
# 2139 l3y matches left
# Client: 340
# 1954114 locations found
# 665806 unique matches
# l3y_o
# 65294 l3y unique matches
# 14925 l3y matches left
# Client: 341
# 318576 locations found
# 99714 unique matches
# l3y_o
# 9565 l3y unique matches
# 2538 l3y matches left
# Client: 342
# 32617 locations found
# 8779 unique matches
# l3y_o
# 567 l3y unique matches
# 375 l3y matches left
# Client: 343
# 1806686 locations found
# 155776 unique matches
# l3y_o
# 16256 l3y unique matches
# 2629 l3y matches left
# Client: 344
# 278033 locations found
# 51230 unique matches
# l3y_o
# 7101 l3y unique matches
# 837 l3y matches left
# Client: 345
# 1913111 locations found
# 344287 unique matches
# l3y_o
# 57638 l3y unique matches
# 15473 l3y matches left
# Client: 346
# 478969 locations found
# 64073 unique matches
# l3y_o
# 8238 l3y unique matches
# 3088 l3y matches left
# Client: 347
# 39003 locations found
# 7005 unique matches
# l3y_o
# 1330 l3y unique matches
# 953 l3y matches left
# Client: 348
# 0 locations found
# 0 unique matches
# Client: 349
# 267119 locations found
# 97186 unique matches
# l3y_o
# 14797 l3y unique matches
# 2558 l3y matches left
# Client: 350
# 2282817 locations found
# 438180 unique matches
# l3y_o
# 61738 l3y unique matches
# 23627 l3y matches left
# Client: 351
# 1783011 locations found
# 349314 unique matches
# l3y_o
# 51595 l3y unique matches
# 9485 l3y matches left
# Client: 352
# 19041 locations found
# 9359 unique matches
# l3y_o
# 4844 l3y unique matches
# 1258 l3y matches left
# Client: 353
# 2057307 locations found
# 466159 unique matches
# l3y_o
# 70955 l3y unique matches
# 18661 l3y matches left
# Client: 354
# 117840 locations found
# 37870 unique matches
# l3y_o
# 7906 l3y unique matches
# 802 l3y matches left
# Client: 355
# 279401 locations found
# 49023 unique matches
# l3y_o
# 16559 l3y unique matches
# 7383 l3y matches left
# Client: 356
# 27569 locations found
# 4289 unique matches
# l3y_o
# 483 l3y unique matches
# 230 l3y matches left
# Client: 357
# 13174 locations found
# 8127 unique matches
# l3y_o
# 2239 l3y unique matches
# 647 l3y matches left
# Client: 358
# 20520 locations found
# 11023 unique matches
# l3y_o
# 1844 l3y unique matches
# 1621 l3y matches left
# Client: 359
# 2304990 locations found
# 356298 unique matches
# l3y_o
# 24125 l3y unique matches
# 7198 l3y matches left
# Client: 360
# 1046 locations found
# 597 unique matches
# l3y_o
# 258 l3y unique matches
# 39 l3y matches left
# Client: 361
# 1059942 locations found
# 205301 unique matches
# l3y_o
# 22731 l3y unique matches
# 4251 l3y matches left
# Client: 362
# 430685 locations found
# 147792 unique matches
# l3y_o
# 35575 l3y unique matches
# 4890 l3y matches left
# Client: 363
# 1825726 locations found
# 314259 unique matches
# l3y_o
# 38665 l3y unique matches
# 4167 l3y matches left
# Client: 364
# 294576 locations found
# 56542 unique matches
# l3y_o
# 7671 l3y unique matches
# 1016 l3y matches left
# Client: 365
# 271571 locations found
# 87752 unique matches
# l3y_o
# 12753 l3y unique matches
# 962 l3y matches left
# Client: 366
# 79617 locations found
# 36054 unique matches
# l3y_o
# 12245 l3y unique matches
# 2631 l3y matches left
# Client: 367
# 4409 locations found
# 1270 unique matches
# l3y_o
# 220 l3y unique matches
# 75 l3y matches left
# Client: 368
# 915860 locations found
# 239239 unique matches
# l3y_o
# 16113 l3y unique matches
# 1777 l3y matches left
# Client: 369
# 213419 locations found
# 114224 unique matches
# l3y_o
# 29773 l3y unique matches
# 8401 l3y matches left
# Client: 370
# 382316 locations found
# 113525 unique matches
# l3y_o
# 19287 l3y unique matches
# 3130 l3y matches left
# Client: 371
# 881729 locations found
# 178545 unique matches
# l3y_o
# 5774 l3y unique matches
# 392 l3y matches left
# Client: 372
# 2307655 locations found
# 597132 unique matches
# l3y_o
# 77397 l3y unique matches
# 14792 l3y matches left
# Client: 373
# 918348 locations found
# 156756 unique matches
# l3y_o
# 17420 l3y unique matches
# 8943 l3y matches left
# Client: 374
# 943269 locations found
# 187418 unique matches
# l3y_o
# 20591 l3y unique matches
# 4248 l3y matches left
# Client: 375
# 3356624 locations found
# 492169 unique matches
# l3y_o
# 87217 l3y unique matches
# 27422 l3y matches left
